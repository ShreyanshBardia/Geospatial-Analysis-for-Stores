# %% [markdown]
# Geospatial Analysis:
#
# The objective of this project is to use geospatial analysis to make decisions about opening up new restaurants(or retail stores, bank branches, airports, etc). For our analysis, we use dataset(scraped from respective websites) consisting of Starbucks, McDonalds and Dominos store coordinates in Mumbai.
#
# This consists of the following steps:
#
#
# 1.   Compute the distance of the stores
# 2.   Visualize data on a map
# 3.   Compute number of stores located in a given radius
# 4.   Compute the closest and farthest stores from Chatrapati Shivaji Maharaj Airport
#
# Github doesn't render follium maps, to see this notebook properly kindly visit [here](https://colab.research.google.com/drive/1aTYU2ac1kktnBrDOnUfc0BB7ic_puFIm?usp=sharing)

# %%
import pandas as pd
import numpy as np
import folium
from sklearn.metrics.pairwise import haversine_distances
import geopy.distance

# %%
#Read file containing location details
dominos = pd.read_csv("/content/dominos_latlong.csv")
mcdonalds = pd.read_csv("/content/mcdonalds_latlong.csv")
starbucks = pd.read_csv("/content/starbucks_latlong.csv")

# %%
dominos.shape[0],mcdonalds.shape[0],starbucks.shape[0]
# Out:
# (104, 74, 57)

# %%
dominos["Store"]="Dominos"
mcdonalds["Store"]="Mcdonalds"
starbucks["Store"]="Starbucks"

# %%
df=pd.concat([dominos,mcdonalds,starbucks])
df.head()
# Out:
#     Latitude  Longitude                                            Address  \
# 0  19.112406  72.867027  124,kapadia industrial estate,near sangam thea...
# 1  19.030440  72.867150  GROUND FLOOR,SHOP NO-A14 &amp;amp; A-15A-2, WI...
# 2  19.165475  72.850754  Shop No2 Ground floor Anupam Chitra Mandir Aar...
# 3  19.067650  72.833380  SHOP NO.1, GROUND FLOOR,MANGAL BHAVAN,PLOT 614...
# 4  19.062554  72.849567  Shop No. 8, Ground Floor, Mumbai Suburban Zill...
#
#      Store
# 0  Dominos
# 1  Dominos
# 2  Dominos
# 3  Dominos
# 4  Dominos

# %%
df.reset_index(drop=True,inplace=True)

# %%
#Merge Columns
df['Coordinate'] = '(' + df['Latitude'].astype(str) + ', ' + df['Longitude'].astype(str) + ')'
df.head(10)
# Out:
#     Latitude  Longitude                                            Address  \
# 0  19.112406  72.867027  124,kapadia industrial estate,near sangam thea...
# 1  19.030440  72.867150  GROUND FLOOR,SHOP NO-A14 &amp;amp; A-15A-2, WI...
# 2  19.165475  72.850754  Shop No2 Ground floor Anupam Chitra Mandir Aar...
# 3  19.067650  72.833380  SHOP NO.1, GROUND FLOOR,MANGAL BHAVAN,PLOT 614...
# 4  19.062554  72.849567  Shop No. 8, Ground Floor, Mumbai Suburban Zill...
# 5  19.141680  72.931300  Restaurant No.1,Gauri Arcade(Punjab Hindu Hote...
# 6  19.240398  72.854753  SHOP NO. 8-11,BETHLEHEM APARTMENTS,400, S.V.P....
# 7  19.220498  72.853544  Shop no. 20,21,22,23,24,25&amp;Shop No.Dâ€“4,2...
# 8  18.970420  72.831260  Shop no 10, Ground floor,1st Al-Hafiz Manzil,R...
# 9  18.975297  72.834844  GROUND FLOOR, 163 VICTORIA ROAD, SANT SAVTA MA...
#
#      Store                  Coordinate
# 0  Dominos  (19.11240634, 72.86702749)
# 1  Dominos        (19.03044, 72.86715)
# 2  Dominos  (19.16547504, 72.85075422)
# 3  Dominos        (19.06765, 72.83338)
# 4  Dominos    (19.06255385, 72.849567)
# 5  Dominos         (19.14168, 72.9313)
# 6  Dominos  (19.24039819, 72.85475281)
# 7  Dominos  (19.22049777, 72.85354435)
# 8  Dominos        (18.97042, 72.83126)
# 9  Dominos  (18.97529741, 72.83484399)

# %%
#Mumbai Chatrapati Shivaji Maharaj Airport Lat Long (Looking for any approx center point)
Mum_coord = (19.094926150826847, 72.86312900618377)

# %% [markdown]
# **1. Compute the distance of the stores**

# %%
#Compute distance of every store from city center
distances_km = []

for row in df.itertuples(index=False):
   distances_km.append(
       geopy.distance.distance(Mum_coord, row.Coordinate).km
   )

df['Distance'] = distances_km
df.head(10)
# Out:
#     Latitude  Longitude                                            Address  \
# 0  19.112406  72.867027  124,kapadia industrial estate,near sangam thea...
# 1  19.030440  72.867150  GROUND FLOOR,SHOP NO-A14 &amp;amp; A-15A-2, WI...
# 2  19.165475  72.850754  Shop No2 Ground floor Anupam Chitra Mandir Aar...
# 3  19.067650  72.833380  SHOP NO.1, GROUND FLOOR,MANGAL BHAVAN,PLOT 614...
# 4  19.062554  72.849567  Shop No. 8, Ground Floor, Mumbai Suburban Zill...
# 5  19.141680  72.931300  Restaurant No.1,Gauri Arcade(Punjab Hindu Hote...
# 6  19.240398  72.854753  SHOP NO. 8-11,BETHLEHEM APARTMENTS,400, S.V.P....
# 7  19.220498  72.853544  Shop no. 20,21,22,23,24,25&amp;Shop No.Dâ€“4,2...
# 8  18.970420  72.831260  Shop no 10, Ground floor,1st Al-Hafiz Manzil,R...
# 9  18.975297  72.834844  GROUND FLOOR, 163 VICTORIA ROAD, SANT SAVTA MA...
#
#      Store                  Coordinate   Distance
# 0  Dominos  (19.11240634, 72.86702749)   1.977948
# 1  Dominos        (19.03044, 72.86715)   7.150689
# 2  Dominos  (19.16547504, 72.85075422)   7.917098
# 3  Dominos        (19.06765, 72.83338)   4.349484
# 4  Dominos    (19.06255385, 72.849567)   3.857181
# 5  Dominos         (19.14168, 72.9313)   8.844935
# 6  Dominos  (19.24039819, 72.85475281)  16.126979
# 7  Dominos  (19.22049777, 72.85354435)  13.936538
# 8  Dominos        (18.97042, 72.83126)  14.184353
# 9  Dominos  (18.97529741, 72.83484399)  13.572638

# %% [markdown]
# **2.Visualize data on a map**

# %%
#Chatrapati Shivaji Maharaj Airport coordinates
m = folium.Map(location=Mum_coord, zoom_start= 5)

#Place markers for the stores on the map
for i, row in df.iterrows():
  lat = df.at[i, 'Latitude']
  lng = df.at[i, 'Longitude']
  store = df.at[i, 'Store']
  if store == 'Mcdonalds':
    color = 'red'
  elif store == 'Starbucks':
    color = 'green'
  else:
    color="blue"
  folium.Marker(location=[lat,lng], popup=(store+row.Coordinate), icon= folium.Icon(color=color)).add_to(m)

loc="Chatrapati Shivaji Maharaj Airport"
folium.Marker(location=[*Mum_coord], popup=(loc+f"{Mum_coord}"), icon= folium.Icon(color="purple")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_23febd0b6a6be6dacdf0a1fa8f04b82e {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_23febd0b6a6be6dacdf0a1fa8f04b82e&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_23febd0b6a6be6dacdf0a1fa8f04b82e = L.map(
#         &#x27;map_23febd0b6a6be6dacdf0a1fa8f04b82e&#x27;, {
#         center: [19.094926150826847, 72.86312900618377],
#         zoom: 5,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_43a497309cef0aed4831e219af992639 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_23febd0b6a6be6dacdf0a1fa8f04b82e);
#
#         var marker_5e350d289f6228d0384f8a82b9e9fa3f = L.marker(
#             [19.11240634, 72.86702749],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_23febd0b6a6be6dacdf0a1fa8f04b82e);
#
#
#
#                 var icon_008d9bf84ae763cf6f8a4363311c7671 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_5e350d289f6228d0384f8a82b9e9fa3f.setIcon(icon_008d9bf84ae763cf6f8a4363311c7671);
#
#
#             var popup_71f778bcf57239b634444e502dd7742e = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_654d92435cd5cb10b9abe09c1708978d = $(`&lt;div id=&quot;html_654d92435cd5cb10b9abe09c1708978d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dominos(19.11240634, 72.86702749)&lt;/div&gt;`)[0];
#                 popup_71f778bcf57239b634444e502dd7742e.setContent(html_654d92435cd5cb10b9abe09c1708978d);
#
#
#             marker_5e350d289f6228d0384f8a82b9e9fa3f.bindPopup(popup_71f778bcf57239b634444e502dd7742e)
#             ;
#
#
#
#
#         var marker_7d31cf54dd51050b16c291bd33c43049 = L.marker(
#             [19.03044, 72.86715],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_23febd0b6a6be6dacdf0a1fa8f04b82e);
#
#
#
#                 var icon_fad7cc5b5f287becb2cb1b1e524b565b = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_7d31cf54dd51050b16c291bd33c43049.setIcon(icon_fad7cc5b5f287becb2cb1b1e524b565b);
#
#
#             var popup_6345cd61902b2cc0fc2970513b22bfcc = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_eabaef1634131a86bc9878157ff603c5 = $(`&lt;div id=&quot;html_eabaef1634131a86bc9878157ff603c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dominos(19.03044, 72.86715)&lt;/div&gt;`)[0];
#                 popup_6345cd61902b2cc0fc2970513b22bfcc.setContent(html_eabaef1634131a86bc9878157ff603c5);
#
#
#             marker_7d31cf54dd51050b16c291bd33c43049.bindPopup(popup_6345cd61902b2cc0fc2970513b22bfcc)
#             ;
#
#
#
#
#         var marker_7093150032763773e85706a69ec109f6 = L.marker(
#             [19.16547504, 72.85075422],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_23febd0b6a6be6dacdf0a1fa8f04b82e);
#
#
#
#                 var icon_36b06b428345af6372443151e2cb37f3 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_7093150032763773e85706a69ec109f6.setIcon(icon_36b06b428345af6372443151e2cb37f3);
#
#
#             var popup_48f26a5ba17632a54c3f491541ddff8d = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_64852f41e7fdef84c877a4bc75f4e04c = $(`&lt;div id=&quot;html_64852f41e7fdef84c877a4bc75f4e04c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dominos(19.16547504, 72.85075422)&lt;/div&gt;`)[0];
#                 popup_48f26a5ba17632a54c3f491541ddff8d.setContent(html_64852f41e7fdef84c877a4bc75f4e04c);
#
#
#             marker_7093150032763773e85706a69ec109f6.bindPopup(popup_48f26a5ba17632a54c3f491541ddff8d)
#             ;
#
#
#
#
#         var marker_80d686ca089707efff6b459d282cd675 = L.marker(
#             [19.06765, 72.83338],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_23febd0b6a6be6dacdf0a1fa8f04b82e);
#
#
#
#                 var icon_e95a178740991cd08c9b0ea24ecfb991 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     pref

# %% [markdown]
# #### A number of observations can be made from the above map
# 1. Majority of starbucks are located on the southern side of Mumbai
# 3. Similarly eastern side has less number of Starbucks stores
# 4. Comparatively there are fewer number of McDonalds in the southern side than Northern side.
# 5. Clearly Dominos has the highest number of stores and they seem to be equally spreadout all over the city.
# 6. There are several parts of the city which has no stores of any of the brands such as Gaikawad Nagar, Gorai beach side etc.. These areas can further be analysed by the companies for considering a store there.
# 7. Starbcuks can consider opening more stores in the northern and eastern part of city.
# 8. Even Borivali has only 2 Starbcuks near it as compared to higher number of Dominos and McDonalds.
# 9. Mahul area also seems to be desolate from any of stores by these brands.

# %% [markdown]
# **3. Compute number of stores located in a given radius**

# %%
#All stores at a distance greater/less than x kms
df[df['Distance'] > 10]
# Out:
#       Latitude  Longitude                                            Address  \
# 6    19.240398  72.854753  SHOP NO. 8-11,BETHLEHEM APARTMENTS,400, S.V.P....
# 7    19.220498  72.853544  Shop no. 20,21,22,23,24,25&amp;Shop No.Dâ€“4,2...
# 8    18.970420  72.831260  Shop no 10, Ground floor,1st Al-Hafiz Manzil,R...
# 9    18.975297  72.834844  GROUND FLOOR, 163 VICTORIA ROAD, SANT SAVTA MA...
# 10   19.216081  72.834259  GROUND FLOOR, SHOP NO.2, CHARKOP AKHAND BHARAT...
# ..         ...        ...                                                ...
# 230  19.165780  73.075340  Kalyan - Shilphata Road,  Palava City, Dombivl...
# 231  19.227945  72.970258  Gladys Alwares Road, Off Pokhran Road No. 2, T...
# 232  19.202660  72.965530  Upper Ground Level, Korum Mall, Off Eastern Ex...
# 233  19.256170  72.983900  Ground Floor, The Walk, Hiranandani estate, Th...
# 234  19.208460  72.971540  Ground Floor, Viviana Mall, Opp Eastern Expres...
#
#          Store                  Coordinate   Distance
# 6      Dominos  (19.24039819, 72.85475281)  16.126979
# 7      Dominos  (19.22049777, 72.85354435)  13.936538
# 8      Dominos        (18.97042, 72.83126)  14.184353
# 9      Dominos  (18.97529741, 72.83484399)  13.572638
# 10     Dominos  (19.21608069, 72.83425927)  13.750627
# ..         ...                         ...        ...
# 230  Starbucks        (19.16578, 73.07534)  23.664183
# 231  Starbucks      (19.227945, 72.970258)  18.541731
# 232  Starbucks        (19.20266, 72.96553)  16.070508
# 233  Starbucks         (19.25617, 72.9839)  21.907526
# 234  Starbucks        (19.20846, 72.97154)  16.970653
#
# [138 rows x 6 columns]

# %%
print(f"Within 2km radius of airport there are {df[df['Distance']<2].shape[0]} stores")
# Out:
# Within 2km radius of airport there are 8 stores

# %% [markdown]
# **4. Compute the closest and farthest stores from Chatrapati Shivaji Maharaj Airport**

# %%
df_farthest = df.iloc[df.groupby('Store')['Distance'].agg(pd.Series.idxmax)]
df_closest = df.iloc[df.groupby('Store')['Distance'].agg(pd.Series.idxmin)]
df_new = pd.concat([df_farthest, df_closest])

# %%
df_new
# Out:
#       Latitude  Longitude                                            Address  \
# 72   19.166099  73.243264   Ground Floor Mandavkar Complex Badlapur West ...
# 171  19.678909  72.908111  Food Hub Mall Opposite Apple RestaurantHaloli ...
# 209  19.442778  73.302500        National Highway 3 , Asangaon Mumbai 421601
# 57   19.096660  72.851950  SHRIRANG APARTMENTGROUND FLOORNEHRU ROADVILE P...
# 107  19.100260  72.840710  Ground Floor,Liberty Lodge, D.J.MargVile Parle...
# 183  19.091980  72.856060  Terminal 1B, Domestic Arrivals, Santa Cruz (Ea...
#
#          Store                  Coordinate   Distance
# 72     Dominos  (19.16609881, 73.24326445)  40.762495
# 171  Mcdonalds      (19.678909, 72.908111)  64.817459
# 209  Starbucks       (19.4427778, 73.3025)  60.132748
# 57     Dominos        (19.09666, 72.85195)   1.191938
# 107  Mcdonalds        (19.10026, 72.84071)   2.431922
# 183  Starbucks        (19.09198, 72.85606)   0.812238

# %% [markdown]
# 1. Strabucks is the closes store followed by Dominos and then Mcdonalds
# 2. This can be further used to find the closes store from any given coordinate when thinking of opening new stores

# %%
#Chatrapati Shivaji Maharaj Airport coordinates
m = folium.Map(location=[*Mum_coord], zoom_start= 10)

for i, rown in df_new.iterrows():
  lat = df_new.at[i, 'Latitude']
  lng = df_new.at[i, 'Longitude']
  store = df_new.at[i, 'Store']

  if store == 'Mcdonalds':
    color = 'red'
  elif store == 'Starbucks':
    color = 'green'
  else:
    color = "blue"

  folium.Marker(location=[lat,lng], popup=store, icon= folium.Icon(color=color)).add_to(m)
folium.Marker(location=[*Mum_coord], popup=(loc+f"{Mum_coord}"), icon= folium.Icon(color="purple")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_aa84b6631e1b78c7e85391e8b455ab05 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_aa84b6631e1b78c7e85391e8b455ab05&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_aa84b6631e1b78c7e85391e8b455ab05 = L.map(
#         &#x27;map_aa84b6631e1b78c7e85391e8b455ab05&#x27;, {
#         center: [19.094926150826847, 72.86312900618377],
#         zoom: 10,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_e56702b1b19411920635d8298d3e8f73 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_aa84b6631e1b78c7e85391e8b455ab05);
#
#         var marker_b335e1aee16c9a912c70adbe59a61cb4 = L.marker(
#             [19.16609881, 73.24326445],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_aa84b6631e1b78c7e85391e8b455ab05);
#
#
#
#                 var icon_956762e4688585ef4dcc3318ef6c40ac = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_b335e1aee16c9a912c70adbe59a61cb4.setIcon(icon_956762e4688585ef4dcc3318ef6c40ac);
#
#
#             var popup_69eb8546b5f96f2d4aaf0d66d172e5ce = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_e7417a3677764852341c78d017032a60 = $(`&lt;div id=&quot;html_e7417a3677764852341c78d017032a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dominos&lt;/div&gt;`)[0];
#                 popup_69eb8546b5f96f2d4aaf0d66d172e5ce.setContent(html_e7417a3677764852341c78d017032a60);
#
#
#             marker_b335e1aee16c9a912c70adbe59a61cb4.bindPopup(popup_69eb8546b5f96f2d4aaf0d66d172e5ce)
#             ;
#
#
#
#
#         var marker_a2c34a3ff78adcdd7aabb71ed9b26c45 = L.marker(
#             [19.678909, 72.908111],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_aa84b6631e1b78c7e85391e8b455ab05);
#
#
#
#                 var icon_b22badc7dea35d42d38383f6be1b7b87 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_a2c34a3ff78adcdd7aabb71ed9b26c45.setIcon(icon_b22badc7dea35d42d38383f6be1b7b87);
#
#
#             var popup_9be36a2984eded9af6583199cca4c16f = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_e11f0e58cad2b9afb1655deab11afaa8 = $(`&lt;div id=&quot;html_e11f0e58cad2b9afb1655deab11afaa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mcdonalds&lt;/div&gt;`)[0];
#                 popup_9be36a2984eded9af6583199cca4c16f.setContent(html_e11f0e58cad2b9afb1655deab11afaa8);
#
#
#             marker_a2c34a3ff78adcdd7aabb71ed9b26c45.bindPopup(popup_9be36a2984eded9af6583199cca4c16f)
#             ;
#
#
#
#
#         var marker_67ea8eb574076374265670e32f26431b = L.marker(
#             [19.4427778, 73.3025],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_aa84b6631e1b78c7e85391e8b455ab05);
#
#
#
#                 var icon_d130ecbe9db9be269201984f95f26bed = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;green&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_67ea8eb574076374265670e32f26431b.setIcon(icon_d130ecbe9db9be269201984f95f26bed);
#
#
#             var popup_5073122c53a49ccf4bb99c4f3efc8350 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_2f740fbd4089d42de28cf0c664e3cdcb = $(`&lt;div id=&quot;html_2f740fbd4089d42de28cf0c664e3cdcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#                 popup_5073122c53a49ccf4bb99c4f3efc8350.setContent(html_2f740fbd4089d42de28cf0c664e3cdcb);
#
#
#             marker_67ea8eb574076374265670e32f26431b.bindPopup(popup_5073122c53a49ccf4bb99c4f3efc8350)
#             ;
#
#
#
#
#         var marker_13dda835029383d150f93603198f625e = L.marker(
#             [19.09666, 72.85195],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_aa84b6631e1b78c7e85391e8b455ab05);
#
#
#
#                 var icon_0e082f9f5a9ab2f2d2599e66e6c1c6a5 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-

# %% [markdown]
# ###Now lets examine the stores which are extremely near to each other and can be considered for merging.

# %%
def closest_stores(store,name,num):
  store_radians=store[["Latitude","Longitude"]].apply(np.radians)  
  A=(haversine_distances(store_radians)) * 6371000/1000
  A=np.triu(A)
  A[A==0]=np.inf
  z=store.shape[0]
  idx=(np.argpartition(A.flatten(),num))[:num]
  indices=[*(idx//z),*(idx%z)]
  m = folium.Map(location=[*Mum_coord], zoom_start= 10)

  for i in indices:
    lat = store.at[i, 'Latitude']
    lng = store.at[i, 'Longitude']
    folium.Marker(location=[lat,lng], popup=name, icon= folium.Icon(color="blue")).add_to(m)
  
  return m,list(zip((idx//z),(idx%z),(A.flatten()[idx])))

# %% [markdown]
# #McDonalds

# %%
m,pair_ids=closest_stores(mcdonalds,"McDonalds",6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_40b4638df1b23bce8a899ea96e2391c7 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_40b4638df1b23bce8a899ea96e2391c7&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_40b4638df1b23bce8a899ea96e2391c7 = L.map(
#         &#x27;map_40b4638df1b23bce8a899ea96e2391c7&#x27;, {
#         center: [19.094926150826847, 72.86312900618377],
#         zoom: 10,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_637164425800437a1b2cba78de265078 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_40b4638df1b23bce8a899ea96e2391c7);
#
#         var marker_511f7d48fe245d8b11a52b6ea481e3c0 = L.marker(
#             [19.141738, 72.931891],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_40b4638df1b23bce8a899ea96e2391c7);
#
#
#
#                 var icon_0e33efa7fe313f25e22ad59845b999f9 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_511f7d48fe245d8b11a52b6ea481e3c0.setIcon(icon_0e33efa7fe313f25e22ad59845b999f9);
#
#
#             var popup_fc3d44acbdf6faae6fcc3b031d0cc67f = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_1b0b6702d92a583f731034de13a6c9d8 = $(`&lt;div id=&quot;html_1b0b6702d92a583f731034de13a6c9d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#                 popup_fc3d44acbdf6faae6fcc3b031d0cc67f.setContent(html_1b0b6702d92a583f731034de13a6c9d8);
#
#
#             marker_511f7d48fe245d8b11a52b6ea481e3c0.bindPopup(popup_fc3d44acbdf6faae6fcc3b031d0cc67f)
#             ;
#
#
#
#
#         var marker_b2950834458bf4e0ca7827d800b6c936 = L.marker(
#             [19.099629, 72.916448],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_40b4638df1b23bce8a899ea96e2391c7);
#
#
#
#                 var icon_100bdb0d26262edc6b53d96c9fcddc1e = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_b2950834458bf4e0ca7827d800b6c936.setIcon(icon_100bdb0d26262edc6b53d96c9fcddc1e);
#
#
#             var popup_81fd45a686ad7aa820318b8ed0adc272 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_680315e5a5e94c0e552c3d0bf3ce5c62 = $(`&lt;div id=&quot;html_680315e5a5e94c0e552c3d0bf3ce5c62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#                 popup_81fd45a686ad7aa820318b8ed0adc272.setContent(html_680315e5a5e94c0e552c3d0bf3ce5c62);
#
#
#             marker_b2950834458bf4e0ca7827d800b6c936.bindPopup(popup_81fd45a686ad7aa820318b8ed0adc272)
#             ;
#
#
#
#
#         var marker_9494a426dba5cb921760ce53c8445d06 = L.marker(
#             [19.229087, 73.123321],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_40b4638df1b23bce8a899ea96e2391c7);
#
#
#
#                 var icon_f283b89270cead95878edaa9403e0329 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_9494a426dba5cb921760ce53c8445d06.setIcon(icon_f283b89270cead95878edaa9403e0329);
#
#
#             var popup_ae1fe8642514e702068c0dde21a7e1c4 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_a46828fff91c6f31023006757c503adb = $(`&lt;div id=&quot;html_a46828fff91c6f31023006757c503adb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#                 popup_ae1fe8642514e702068c0dde21a7e1c4.setContent(html_a46828fff91c6f31023006757c503adb);
#
#
#             marker_9494a426dba5cb921760ce53c8445d06.bindPopup(popup_ae1fe8642514e702068c0dde21a7e1c4)
#             ;
#
#
#
#
#         var marker_f170bd70d253eb60284212890a63b7c7 = L.marker(
#             [19.11961, 72.84606],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_40b4638df1b23bce8a899ea96e2391c7);
#
#
#
#                 var icon_527ff706144c770d1fa2af9e144e8350 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-r

# %%
pair_ids.sort(key=lambda x: x[2])
print("McDonalds")
for x in (pair_ids):
  a,b,dist=x
  print(f"Store 1 Address: {mcdonalds.iloc[a].Address}",
        f"Store 2 Address: {mcdonalds.iloc[b].Address}",
        f"Distance:{dist:.2}km",
        sep="\n",
        end="\n\n\n")
# Out:
# McDonalds
# Store 1 Address: Unit No T-2C, 3rd Floor, R CityLBS Marg, Ghatkopar West,Mumbai 400 086, Ghatkopar, Maharashatra
# Store 2 Address: Unit no G- 57C, Ground Floor, R CityLBS Marg, Ghatkopar West,Mumbai 400 086, Ghatkopar, Maharashatra
# Distance:0.028km
#
#
# Store 1 Address: 18, Unity Mansion, Gazdar RoadOpp Andheri Station, Andheri (w),Mumbai 400 058.
# Store 2 Address: Shirin Mansion, Ground Floor, Shop No 1, Gazder Road, Mumbail, Maharashtra 400058, India
# Distance:0.028km
#
#
# Store 1 Address: Magnet Mal -BhandupNeptune Magnet MallLBS Marg, Bandup - WestMumbai -78
# Store 2 Address: Magnet Mal -Bhandup, Unit no F-3023rd Floor, Neptune Magnet MallLBS Marg, Bandup - WestMumbai -78
# Distance:0.035km
#
#
# Store 1 Address: Ground Floor – G44 & G45, Metro JunctionNetivali Baug Shil Phata Road,Kalyan – 421 306. Tel No.9970022132
# Store 2 Address: 2nd Floor , KS 37, Metro Junction MalNetivali Baug Shil Phata Road,Kalyan – 421 306.
# Distance:0.13km
#
#
# Store 1 Address: 18, Unity Mansion, Gazdar RoadOpp Andheri Station, Andheri (w),Mumbai 400 058.
# Store 2 Address: Hingu Bhavan, Sahar RoadAndheri East Station, Agarkar ChowkMumbai, Maharashatra 400059
# Distance:0.23km
#
#
# Store 1 Address: Shirin Mansion, Ground Floor, Shop No 1, Gazder Road, Mumbail, Maharashtra 400058, India
# Store 2 Address: Hingu Bhavan, Sahar RoadAndheri East Station, Agarkar ChowkMumbai, Maharashatra 400059
# Distance:0.24km

# %% [markdown]
# #Dominos

# %%
m,pair_ids=closest_stores(dominos,"Dominos",6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_9076035c084cf04e32dc196494feeec6 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_9076035c084cf04e32dc196494feeec6&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_9076035c084cf04e32dc196494feeec6 = L.map(
#         &#x27;map_9076035c084cf04e32dc196494feeec6&#x27;, {
#         center: [19.094926150826847, 72.86312900618377],
#         zoom: 10,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_0d371d21c11b6c7d63335d48cd64b9df = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_9076035c084cf04e32dc196494feeec6);
#
#         var marker_fdf92a1e85304ffcf96f664f18f6ecde = L.marker(
#             [19.14143911, 72.82485256],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_9076035c084cf04e32dc196494feeec6);
#
#
#
#                 var icon_c13610a6d1c67e05a461b3104739e343 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_fdf92a1e85304ffcf96f664f18f6ecde.setIcon(icon_c13610a6d1c67e05a461b3104739e343);
#
#
#             var popup_15efc41e2a6be08d8867d6be9ce6da1c = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_fae0439e2081a5afd6fa54e9a382be93 = $(`&lt;div id=&quot;html_fae0439e2081a5afd6fa54e9a382be93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dominos&lt;/div&gt;`)[0];
#                 popup_15efc41e2a6be08d8867d6be9ce6da1c.setContent(html_fae0439e2081a5afd6fa54e9a382be93);
#
#
#             marker_fdf92a1e85304ffcf96f664f18f6ecde.bindPopup(popup_15efc41e2a6be08d8867d6be9ce6da1c)
#             ;
#
#
#
#
#         var marker_56e42c4617512b411c5c1893cea88003 = L.marker(
#             [19.17729265, 72.85518136],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_9076035c084cf04e32dc196494feeec6);
#
#
#
#                 var icon_57a2692cbf2abb08727ba1408ecc5d07 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_56e42c4617512b411c5c1893cea88003.setIcon(icon_57a2692cbf2abb08727ba1408ecc5d07);
#
#
#             var popup_4222281a4affe2e43c4509cc6f0e8094 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_3171c6a897ee0e19b57f0897a6d1e049 = $(`&lt;div id=&quot;html_3171c6a897ee0e19b57f0897a6d1e049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dominos&lt;/div&gt;`)[0];
#                 popup_4222281a4affe2e43c4509cc6f0e8094.setContent(html_3171c6a897ee0e19b57f0897a6d1e049);
#
#
#             marker_56e42c4617512b411c5c1893cea88003.bindPopup(popup_4222281a4affe2e43c4509cc6f0e8094)
#             ;
#
#
#
#
#         var marker_b116b2f508796024893ffd299f730de7 = L.marker(
#             [19.16547504, 72.85075422],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_9076035c084cf04e32dc196494feeec6);
#
#
#
#                 var icon_5c875d3adbae928133639f0f55c5c90e = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_b116b2f508796024893ffd299f730de7.setIcon(icon_5c875d3adbae928133639f0f55c5c90e);
#
#
#             var popup_ff805fe0be0dcff5efac95cf18b534c9 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_e2fecfbe3f1f0714d707b7255d10d2f0 = $(`&lt;div id=&quot;html_e2fecfbe3f1f0714d707b7255d10d2f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dominos&lt;/div&gt;`)[0];
#                 popup_ff805fe0be0dcff5efac95cf18b534c9.setContent(html_e2fecfbe3f1f0714d707b7255d10d2f0);
#
#
#             marker_b116b2f508796024893ffd299f730de7.bindPopup(popup_ff805fe0be0dcff5efac95cf18b534c9)
#             ;
#
#
#
#
#         var marker_f73771cc9e36257d44f22877c0d2c67d = L.marker(
#             [19.05378, 72.89465],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_9076035c084cf04e32dc196494feeec6);
#
#
#
#                 var icon_47f177b6bf456d0c7072dca6fa361c08 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x2

# %%
pair_ids.sort(key=lambda x: x[2])
print("Dominos")
for x in (pair_ids):
  a,b,dist=x
  print(f"Store 1 Address: {dominos.iloc[a].Address} LatLng: {dominos.iloc[a].Latitude,dominos.iloc[a].Longitude}",
        f"Store 2 Address: {dominos.iloc[b].Address} LatLng: {dominos.iloc[b].Latitude,dominos.iloc[b].Longitude}",
        f"Distance:{dist:.2}km",
        sep="\n",
        end="\n\n\n")
# Out:
# Dominos
# Store 1 Address: Shop No18 GF,101,101A FF,GreenVille CHS,Opp:Samartha Vaibhav,Lokhandwala Complex,Andheri west,Mumbai- 400053 Maharashtra LatLng: (19.14143911, 72.82485256)
# Store 2 Address: 12/13,KAMDHENU SHOPPING COMPLEX,LOKHANDWALA COMPLEX,ANDHERI (W),MUMBAI - 400058 PH.NO. 022-26326699/ 26326725/ 26/ 26324465/ 26366445/ 46/ 26366430/ 26322562/ 26324705/ 26326705 LatLng: (19.14145214, 72.82477479)
# Distance:0.0083km
#
#
# Store 1 Address: SHOP NO. 6, GOREGAON MALAD LINK ROAD,JAGDAMBA COMMERCIAL COMPLEX,NEXT TO MOVIE TIME CINEMA,MALAD(W),MUMBAI - 400064 PH.NO. 022-28443553/ 28446191/ 28443602/ 28805219/ 28813887/ 28449531/ 28445592/ 28446772 LatLng: (19.17729265, 72.85518136)
# Store 2 Address: SHOP 14A , 15A , 9C GROUND FLOOR SHREE KRISHNA HEIGHTS COOPERATIVE HOUSING SOCIETY LTD , UPPER GOVIND NAGAR , NEXT TO AXIS BANK, MALAD (E),MUMBAI - 400097 PH.NO. 022-42415151 LatLng: (19.17717152, 72.85521001)
# Distance:0.014km
#
#
# Store 1 Address: PLOT NO.609,V.N. PURAV MARG,OPP. AKBARALLY&#039;S,CHEMBUR,MUMBAI - 400071 PH.NO. 022-25298383/ 25298382/ 25298384/ 25298385/ 25298386 LatLng: (19.05378, 72.89465)
# Store 2 Address: Shop Numbers-2,3,4Ground Floor,Chhadva Apartments,CTS Nos-1736-1736/1-7,Sionâ€“Trombay Road,Chembur,Mumbaiâ€“400071PH- 02225266200 LatLng: (19.0532678, 72.89679523)
# Distance:0.23km
#
#
# Store 1 Address: Stall No. 2 and 3, Ground Floor, 03 GBD, Godrej Business District, Vikhroli, Mumbai- 400079PH-022-25188590/1/2/3 LatLng: (19.10232721, 72.92125143)
# Store 2 Address: Shop No. 1 2 &amp; 3 Ground Floor J. K Tower Phirojshah Nagar Road Survey No 41 Hissa No. 3 corresponding to City Survey No. 281 Haryali Village Near Bus Depot  Vikroli East Mumbai  400083 Maharashtra LatLng: (19.10087, 72.91922)
# Distance:0.27km
#
#
# Store 1 Address: Shop No 5,6,7,Ground Floor Kamal Kunj( Nutan Hotel) Rammiling Jee Shukla Marg, Sion Koliwada, Sion East, Mumbai 400022, Maharashtra LatLng: (19.04038918, 72.86432839)
# Store 2 Address: SHOP NO.1-2, GROUND FLOOR,DR. KENI HOUSE, JAIN SOCIETY,S.T. ROAD,SION(W),MUMBAI - 400022 PH.NO. 022-24041780/ 24042119,24041760/ 24041759 LatLng: (19.039, 72.8613)
# Distance:0.35km
#
#
# Store 1 Address: Shop No2 Ground floor Anupam Chitra Mandir Aaray Road Station road Jaiprakash Nagar Goregaon East Mumbai 400063 Maharashtra LatLng: (19.16547504, 72.85075422)
# Store 2 Address: SHOP NO 8GROUND FLOOR,ASHOKRAJ,CO-PERATIVE HOUSING SOCIETY, S.V.RAOD, GOREGAON WEST,,MUMBAI - 400062 PH.NO. 022-28714491/ 92/ 93/ 94/ 95/ 96/ 97/ 98/ 28785975 LatLng: (19.16317, 72.8461)
# Distance:0.55km

# %% [markdown]
# #Starbucks

# %%
m,pair_ids=closest_stores(starbucks,"Starbucks",6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_0d4f9c96fdd583848450acdfd1bc33ce {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_0d4f9c96fdd583848450acdfd1bc33ce&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_0d4f9c96fdd583848450acdfd1bc33ce = L.map(
#         &#x27;map_0d4f9c96fdd583848450acdfd1bc33ce&#x27;, {
#         center: [19.094926150826847, 72.86312900618377],
#         zoom: 10,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_f0abdbe50d276935b3fa1441df4f6f84 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_0d4f9c96fdd583848450acdfd1bc33ce);
#
#         var marker_4d533f7daec88ade6a147d535e3bc641 = L.marker(
#             [19.09932, 72.87473],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_0d4f9c96fdd583848450acdfd1bc33ce);
#
#
#
#                 var icon_3c8ef5f98b28f92a8b22f87ce5ce9f1c = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_4d533f7daec88ade6a147d535e3bc641.setIcon(icon_3c8ef5f98b28f92a8b22f87ce5ce9f1c);
#
#
#             var popup_905d30aa3a60dd47b0bfce21a0910303 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_a04c5521afa8c16ccf1d8b8ad7cfe9b7 = $(`&lt;div id=&quot;html_a04c5521afa8c16ccf1d8b8ad7cfe9b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#                 popup_905d30aa3a60dd47b0bfce21a0910303.setContent(html_a04c5521afa8c16ccf1d8b8ad7cfe9b7);
#
#
#             marker_4d533f7daec88ade6a147d535e3bc641.bindPopup(popup_905d30aa3a60dd47b0bfce21a0910303)
#             ;
#
#
#
#
#         var marker_8a1548e5b4634aee581dbaa39bd1e872 = L.marker(
#             [18.93231, 72.83409],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_0d4f9c96fdd583848450acdfd1bc33ce);
#
#
#
#                 var icon_3daf9dcd188fe1ee1744c73a3dfcf963 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_8a1548e5b4634aee581dbaa39bd1e872.setIcon(icon_3daf9dcd188fe1ee1744c73a3dfcf963);
#
#
#             var popup_106c92ef648e2fbbb1fccbb28f0b1d15 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_17073b559c04df4512f1a5825cae8e69 = $(`&lt;div id=&quot;html_17073b559c04df4512f1a5825cae8e69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#                 popup_106c92ef648e2fbbb1fccbb28f0b1d15.setContent(html_17073b559c04df4512f1a5825cae8e69);
#
#
#             marker_8a1548e5b4634aee581dbaa39bd1e872.bindPopup(popup_106c92ef648e2fbbb1fccbb28f0b1d15)
#             ;
#
#
#
#
#         var marker_701d5e984b74f74fb1625dc7b52ca20e = L.marker(
#             [19.0996, 72.87427],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_0d4f9c96fdd583848450acdfd1bc33ce);
#
#
#
#                 var icon_9fa6dc81c4562ab14c049c16018b1318 = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_701d5e984b74f74fb1625dc7b52ca20e.setIcon(icon_9fa6dc81c4562ab14c049c16018b1318);
#
#
#             var popup_f2c01db2e951cb435bfc82db3cf015c9 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_a81b8154b59ee5e5437977afb7810b7b = $(`&lt;div id=&quot;html_a81b8154b59ee5e5437977afb7810b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#                 popup_f2c01db2e951cb435bfc82db3cf015c9.setContent(html_a81b8154b59ee5e5437977afb7810b7b);
#
#
#             marker_701d5e984b74f74fb1625dc7b52ca20e.bindPopup(popup_f2c01db2e951cb435bfc82db3cf015c9)
#             ;
#
#
#
#
#         var marker_5e550767ad0491f5e963a0dd0ecb7e7e = L.marker(
#             [19.09932, 72.87473],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_0d4f9c96fdd583848450acdfd1bc33ce);
#
#
#
#                 var icon_6cda4cbaddf20e7ab45b5ea415d8149b = L.AwesomeMarkers.icon({
#                     icon: &#x27;info-sign&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0

# %%
pair_ids.sort(key=lambda x: x[2])
print("Starbucks")
for x in (pair_ids):
  a,b,dist=x
  print(f"Store 1 Address: {starbucks.iloc[a].Address} LatLng: {starbucks.iloc[a].Latitude,starbucks.iloc[a].Longitude}",
        f"Store 2 Address: {starbucks.iloc[b].Address} LatLng: {starbucks.iloc[b].Latitude,starbucks.iloc[b].Longitude}",
        f"Distance:{dist:.2}km",
        sep="\n",
        end="\n\n\n")
# Out:
# Starbucks
# Store 1 Address: Terminal 2, International Arrivals, Andheri (East), Mumbai 400099 LatLng: (19.09932, 72.87473)
# Store 2 Address: T2 Departure SHA, Level P9, Food Court Area, Andheri (East), Mumbai 400099 LatLng: (19.0996, 72.87427)
# Distance:0.057km
#
#
# Store 1 Address: Terminal 2, International Arrivals, Andheri (East), Mumbai 400099 LatLng: (19.09932, 72.87473)
# Store 2 Address: Outlet Code 4076, SHA, Level 4 CSMI Airport Mumbai 400099 LatLng: (19.098443, 72.874504)
# Distance:0.1km
#
#
# Store 1 Address: T2 Departure SHA, Level P9, Food Court Area, Andheri (East), Mumbai 400099 LatLng: (19.0996, 72.87427)
# Store 2 Address: Outlet Code 4076, SHA, Level 4 CSMI Airport Mumbai 400099 LatLng: (19.098443, 72.874504)
# Distance:0.13km
#
#
# Store 1 Address: Horniman Circle , Veer Nariman Road, Mumbai 400001 LatLng: (18.93231, 72.83409)
# Store 2 Address: Army and Navy Building,Kala Ghoda, Fort Mumbai 400001 LatLng: (18.930751, 72.833085)
# Distance:0.2km
#
#
# Store 1 Address: Kabra Metro One, Ground Floor,Aram Nagar, Seven Bungalow, Andheri West,Mumbai -400058 LatLng: (19.130571, 72.82218)
# Store 2 Address: Four Bunglows, Andheri (West), Mumbai 400053 LatLng: (19.13123, 72.82476)
# Distance:0.28km
#
#
# Store 1 Address: Ground Floor, Club House, Solitaire Corporate Park, Chakala, Andheri East, Mumbai 400093 LatLng: (19.11194, 72.86084)
# Store 2 Address: Ground Floor, Kanakia Wall Street, Andheri East, Mumbai 400093 LatLng: (19.11484, 72.86121)
# Distance:0.32km
